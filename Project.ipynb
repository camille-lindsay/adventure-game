# %%
def main():
    story = {
        'start': {
            'text': "Congratulations! You have made it into the Hogwarts School of Witchcraft and Wizardry! Now that you have arrived, will you go into the great hall or explore?",
            'choices': {
                'great hall': 'great_hall',
                'explore': 'explore_castle'
            }
        },
        'great_hall': {
            'text': "You end up in the Great Hall and are ushered into the sorting hat line. When you reach the front of the line, the hat starts talking to you. He asks if you enjoy talking to strangers.",
            'choices': {
                'yes': 'enjoy_strangers',
                'no': 'enjoy_strangers'
            }
        },
        'enjoy_strangers': {
            'text': "He then asks you if strangers enjoy talking to you.",
            'choices': {
                'yes': 'ravenclaw',
                'idk': 'gryffindor',
                'why would they?': 'slytherin',
                'yes, i am a great listener': 'hufflepuff'
            }
        },
        'ravenclaw': {
            'text': "RAVENCLAW! he yells. As you make your way to the designated table, you see three pairs of eyes looking at you. Do you...",
            'choices': {
                'smile and wave': 'smile_and_wave_back',
                'sneer at them': 'nonchalant',
                'pretend you do not see them': 'nonchalant'
            }
        },
        'gryffindor': {
            'text': "GRYFFINDOR! he yells. As you make your way to the designated table, you see three pairs of eyes looking at you. Do you...",
            'choices': {
                'smile and wave': 'smile_and_wave_back',
                'sneer at them': 'nonchalant',
                'pretend you do not see them': 'nonchalant'
            }
        },
        'slytherin': {
            'text': "SLYTHERIN! he yells. As you make your way to the designated table, you see three pairs of eyes looking at you. Do you...",
            'choices': {
                'smile and wave': 'smile_and_wave_back',
                'sneer at them': 'nonchalant',
                'pretend you do not see them': 'nonchalant'
            }
        },
        'hufflepuff': {
            'text': "HUFFLEPUFF! he yells. As you make your way to the designated table, you see three pairs of eyes looking at you. Do you...",
            'choices': {
                'smile and wave': 'smile_and_wave_back',
                'sneer at them': 'nonchalant',
                'pretend you do not see them': 'nonchalant'
            }
        },
        'nonchalant': {
            'text': "They look away from you, embarrassed. But as you are following your house back to the dormitory, they stop you. They introduce themselves, 'I am Harry Potter, this is Hermione and Ron, do you want to be friends?' What do you say?",
            'choices': {
                'sure!': 'follow_them',
                'nah': 'safe_ending'
            }
        },
        'smile_and_wave_back': {
            'text': "They smile and wave back at you, and you feel a warm welcome. As you are following your house back to the dormitory, they stop you. They introduce themselves, 'I am Harry Potter, this is Hermione and Ron, do you want to be friends?' What do you say?",
            'choices': {
                'sure!': 'follow_them',
                'nah': 'safe_ending'
            }
        },
        'follow_them': {
            'text': "You follow them, and they show you around the castle, quickly becoming your best friends. 'We have to show you something.' they say. Do you go with them?",
            'choices': {
                'yes': 'go_with_them',
                'no': 'safe_ending'
            }
        },
        'safe_ending': {
            'text': "You decide to keep to yourself for now, focusing on your studies and finding your own way. You live your years lonely and unhappy, but safe.",
            'choices': {}
        },
        'explore_castle': {
            'text': "You start exploring the castle and find a secret corridor. Do you enter or go back?",
            'choices': {
                'enter': 'hidden_passage',
                'go back': 'great_hall'
            }
        },
        'hidden_passage': {
            'text': "left or right fork?",
            'choices': {
                'left': 'dark_forest',
                'right': 'great_hall'
                }
        },
        'dark_forest': {
            'text': "You open a door that leads you outside into the dark forest. Do you turn around?",
            'choices': {
                'yes': 'great_hall',
                'no': 'hooded_figure'
                }
        },
        'hooded_figure': {
            'text': "You continue following the trail and see a hooded figure in the woods. You feel cold...what do you do?",
            'choices': {
                'run': 'hagrid_sees',
                'take your wand out': 'hagrid_sees',
                'stand frozen in fear': 'bad_ending'
                }
        },
        'hagrid_sees': {
            'text': "You feel a hard hand on your shoulder and whip around to see a large man with a bushy, black beard. He introduces himself as Hagrid, and takes you back into the castle.",
            'choices': {
                'follow him': 'great_hall',
                'no': 'bad_ending'
                }
        },
        'bad_ending': {
            'text': "You see a flash of green light and a yell in the background. Avada Kedavra! You died.",
            'choices': {}
        },
        'go_with_them': {
            'text': "They take you outside and into the Forbidden Forest. When you are out there, you hear a rustling noise in the bushes. Do you follow them?",
            'choices': {
                'yes': 'go_with',
                'no': 'bad_ending'
                }
        },
        'go_with': {
            'text':"Out of nowhere, a dark figure jumps out of the foliage. 'I have been waiting for you, Potter,' the figure says. You all whip out your wands and point it at the figure.",
            'choices': {
                'stand with your friends': 'continues',
                'run away': 'bad_ending',
                'attempt to kill the figure': 'attempted_murder'
                }
        },
        'continues': {
            'text': "'Remove your hood!' Harry yells. The figure laughs coldly and says, 'I see you have a new friend, introduce them!'",
            'choices': {
                'scream': 'bad_ending',
                'introduce_yourself': 'say_hi',
                'yell a spell': 'attempted_murder'
                }
        },
        'attempted_murder': {
            'text': "As your spell approaches the figure, the hood falls off to reveal Draco Malfoy. Luckily, Hermione blocks your spell, but you are sent to Azkaban for attempted murder. You lose!",
            'choices': {}
        },
        'say_hi': {
            'text': "You introduce yourself, and the figure laughs. Your friends look at each other, confused. The figure removes his hoo to reveal none other than Professor Dumbledore! He says,'Now I shall show you guys what you came here for.'", 
            'choices': {
                'follow them': 'unicorn',
                'go back': 'safe_ending'
                }
        },
        'unicorn': {
            'text': "You and your friends follow Dumbledore into the forest where you are greeted by an increidible sight...a baby unicorn. You and your friends laugh and stay BFFs forever. This is the happiest ending, CONGRATULATIONS!!",
            'choices': {}
        }
    }

    current_scene = 'start'

    while True:
        scene = story[current_scene]
        print(scene['text'])

        if not scene['choices']:
            break

        for choice in scene['choices']:
            print(f"- {choice}")

        player_choice = input("> ").strip().lower()

        if player_choice in scene['choices']:
            current_scene = scene['choices'][player_choice]
        else:
            print("Invalid choice. Try again.")

    print("The End")

if __name__ == "__main__":
    main()
